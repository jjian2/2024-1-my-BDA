# %% [markdown]
# <a href="https://colab.research.google.com/github/jjian2/2024-1-my-BDA/blob/main/inclass/02w_0318_mon_dataframe_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **빅데이터분석프로그래밍**

# %% [markdown]
# 파이썬 설치 확인

# %%
import sys
import numpy as np
import pandas as pd

print(np. __version__)
print(pd. __version__)
# Out:
# 1.25.2
# 1.5.3

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

plt.plot([-1, 0, 1, 2])
plt.title('그래프 제목')
plt.xlabel('간단한 그래프')
plt.show()

# %% [markdown]
# # 데이터분석을 위한 seaborn 내장(토이) 데이터, titanic

# %%
import seaborn as sns

titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.countplot(titanic, x = "sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(titanic, x = "class")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(data = titanic, x = "class", hue = "alive");

# %%
titanic.pclass.unique()
# Out:
# array([3, 1, 2])

# %%
titanic.pclass.values
# Out:
# array([3, 1, 3, 1, 3, 3, 1, 3, 3, 2, 3, 1, 3, 3, 3, 2, 3, 2, 3, 3, 2, 2,
#        3, 1, 3, 3, 3, 1, 3, 3, 1, 1, 3, 2, 1, 1, 3, 3, 3, 3, 3, 2, 3, 2,
#        3, 3, 3, 3, 3, 3, 3, 3, 1, 2, 1, 1, 2, 3, 2, 3, 3, 1, 1, 3, 1, 3,
#        2, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 3, 3,
#        1, 3, 3, 3, 1, 3, 3, 3, 1, 1, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 3, 3, 3, 2, 1, 3, 2, 3, 2, 2, 1, 3, 3, 3, 3, 3, 3, 3,
#        3, 2, 2, 2, 1, 1, 3, 1, 3, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 1, 3, 3,
#        3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 3,
#        3, 1, 2, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 2, 2, 3, 2, 1, 1, 3, 3,
#        3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 1, 2,
#        3, 2, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3,
#        2, 3, 3, 1, 3, 2, 1, 2, 3, 3, 1, 3, 3, 3, 1, 1, 1, 2, 3, 3, 1, 1,
#        3, 2, 3, 3, 1, 1, 1, 3, 2, 1, 3, 1, 3, 2, 3, 3, 3, 3, 3, 3, 1, 3,
# ...

# %%
titanic.pclass.unique()
# Out:
# array([3, 1, 2])

# %%
titanic.pclass.values

# %%
titanic["pclass"].unique()
# Out:
# array([3, 1, 2])

# %%
titanic.pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
titanic.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
titanic[["pclass", "who"]].values
# Out:
# array([[3, 'man'],
#        [1, 'woman'],
#        [3, 'woman'],
#        ...,
#        [3, 'woman'],
#        [1, 'man'],
#        [3, 'man']], dtype=object)

# %%
titanic.groupby("sex").count()
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
titanic.groupby("class").count()
# Out:
#         survived  pclass  sex  age  sibsp  parch  fare  embarked  who  \
# class
# First        216     216  216  186    216    216   216       214  216
# Second       184     184  184  173    184    184   184       184  184
# Third        491     491  491  355    491    491   491       491  491
#
#         adult_male  deck  embark_town  alive  alone
# class
# First          216   175          214    216    216
# Second         184    16          184    184    184
# Third          491    12          491    491    491

# %%
sns.barplot(x='sex', y='survived', data=titanic);

# %%
sns.barplot(x='pclass', y='survived', data=titanic);

# %%
sns.barplot(x='pclass', y='survived', hue='sex', data=titanic);

# %% [markdown]
# # 단원 4 데이터프레임의 세계로!

# %%
import pandas as pd

df=pd.DataFrame({"name    " : ["김지훈", "이유진", "박동현", "김진지"],
                 "english"  : [90, 80, 60, 70],
                 "math"     : [50, 60, 100, 20]})

df
# Out:
#   name      english  math
# 0      김지훈       90    50
# 1      이유진       80    60
# 2      박동현       60   100
# 3      김진지       70    20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4 non-null      object
#  1   english  4 non-null      int64
#  2   math     4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#          english        math
# count   4.000000    4.000000
# mean   75.000000   57.500000
# std    12.909944   33.040379
# min    60.000000   20.000000
# 25%    67.500000   42.500000
# 50%    75.000000   55.000000
# 75%    82.500000   70.000000
# max    90.000000  100.000000

# %%
df.describe(include='all')
# Out:
#        name        english        math
# count         4   4.000000    4.000000
# unique        4        NaN         NaN
# top         김지훈        NaN         NaN
# freq          1        NaN         NaN
# mean        NaN  75.000000   57.500000
# std         NaN  12.909944   33.040379
# min         NaN  60.000000   20.000000
# 25%         NaN  67.500000   42.500000
# 50%         NaN  75.000000   55.000000
# 75%         NaN  82.500000   70.000000
# max         NaN  90.000000  100.000000

# %% [markdown]
# # 특정 변수의 값 추출하기

# %%
df['math']
# Out:
# 0     50
# 1     60
# 2    100
# 3     20
# Name: math, dtype: int64

# %%
type(df['math'])
# Out:
# pandas.core.series.Series

# %%
sum(df['english'])
# Out:
# 300

# %%
sum(df['math'])
# Out:
# 230

# %%
sum(df['english']) / 4
# Out:
# 75.0

# %%
sum(df['english']) / len(df)
# Out:
# 75.0

# %%
df.sum()
# Out:
# name        김지훈이유진박동현김진지
# english              300
# math                 230
# dtype: object

# %%
df.sum(numeric_only='True')
# Out:
# english    300
# math       230
# dtype: int64

# %%
df.sum(axis=0, numeric_only='True') #세로의 합이 구해짐
# Out:
# english    300
# math       230
# dtype: int64

# %%
df.sum(axis=1, numeric_only='True') #가로의 합이 구해짐
# Out:
# 0    140
# 1    140
# 2    160
# 3     90
# dtype: int64

# %%
df.sum(axis='columns', numeric_only='True')
# Out:
# 0    140
# 1    140
# 2    160
# 3     90
# dtype: int64

# %%
df.sum(axis='index', numeric_only='True')
# Out:
# english    300
# math       230
# dtype: int64

# %%
df.mean(axis='columns', numeric_only='True') #평균
# Out:
# 0    70.0
# 1    70.0
# 2    80.0
# 3    45.0
# dtype: float64

# %%
df.mean(axis='index', numeric_only='True') #평균
# Out:
# english    75.0
# math       57.5
# dtype: float64

# %%
import pandas as pd

fu=pd.DataFrame({"제품"     : ["사과", "딸기", "수박"],
                 "가격"     : [1800, 1500, 3000],
                 "판매량"   : [24, 38, 13]})

fu
# Out:
#    제품    가격  판매량
# 0  사과  1800   24
# 1  딸기  1500   38
# 2  수박  3000   13

# %%
fu.mean(numeric_only='True')

# %% [markdown]
# # 4-3 외부데이터 이용하기  - 축척된 시험 성적 데이터를 불러오자!

# %% [markdown]
# # 정리하기

# %%
#1. 데이터 프레임 만들기
df=pd.DataFrame({"name    " : ["김지훈", "이유진", "박동현", "김진지"],
                 "english"  : [90, 80, 60, 70],
                 "math"     : [50, 60, 100, 20]})

#2. 외부 데이터 이용하기

#엑셀 파일 불러오기
df_exam = pd.read_excel('excel_exam.xlsx')

#CSV 파일 불러오기
df_csv_exam = pd.read_csv('exam.csv')

#CSV 파일로 저장하기
df_midterm = pd.DataFrame({"english"  : [90, 80, 60, 70],
                           "math"     : [50, 60, 100, 20],
                           "nclass"   : [1, 1, 2, 2]})
df_midterm.to_csv('output_newdata2.csv')
df_midterm.to_csv('output_newdata3.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-5336dbd8cda8> in <cell line: 9>()
#       7
#       8 #엑셀 파일 불러오기
# ----> 9 df_exam = pd.read_excel('excel_exam.xlsx')
#      10
#      11 #CSV 파일 불러오기
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
